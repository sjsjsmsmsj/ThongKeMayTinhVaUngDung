# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd

# %%
table = pd.DataFrame({"MSSV": [123, 456], "Ten": ["Nguyen Van A", "Nguyen Thi B"], "Diem": [9, 8]})

# %%
table
# Out:
#    MSSV           Ten  Diem
# 0   123  Nguyen Van A     9
# 1   456  Nguyen Thi B     8

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1, 1, 100)
y = x ** 2
plt.plot(x, y)
plt.show()
